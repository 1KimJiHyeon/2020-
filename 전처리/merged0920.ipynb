# %%
import os
import pandas as pd
import numpy as np

from google.colab import drive

# %%
if not os.path.exists('/content/drive'):
  drive.mount('/content/drive')

# %%
cd '/content/drive/My Drive/dataset'

# %%
df1=pd.read_excel("Merged.xlsx")
df2=pd.read_csv("독거노인 수 전처리.csv")

# %%
from functools import reduce

dfs = [df1, df2]

df= reduce(lambda  left,right: pd.merge(left,right,on=['구','동'], how='outer'), dfs)
df=df.drop(columns=['Unnamed: 0_x','Unnamed: 0.1', 'Unnamed: 0_y'])
df

# %%
df.to_csv("merged0920.csv", mode='w' ,encoding='euc-kr')
