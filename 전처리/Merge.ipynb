# %%
import os
import pandas as pd
import numpy as np

from google.colab import drive

# %%
if not os.path.exists('/content/drive'):
  drive.mount('/content/drive')

# %%
cd '/content/drive/My Drive/dataset'

# %%
df1=pd.read_csv('노인 인구수.csv')
df2=pd.read_csv('문화생활기관.csv')
df3=pd.read_csv('지역별 노인정 수.csv')
df4=pd.read_csv('무료급식소.csv')
df5=pd.read_excel('버스 정보 안내기 수.xlsx')

# %%
from functools import reduce


dfs = [df1, df2, df3, df4, df5]

df= reduce(lambda  left,right: pd.merge(left,right,on=['구','동'], how='outer'), dfs)
df

# %%
df.columns

# %%
df=df.drop(columns=['Unnamed: 0_x','Unnamed: 0_y', 'Unnamed: 0'])

# %%
df.columns

# %%
 df = df[['구','구별 총 노인수', '구별 노인 비율', '구별 문화생활 수', '구별 버스 정보 안내기 수', '동','동별 총 노인수','동별 노인 비율', '동별 문화생활 수','동별 버스 정보 안내기 수','노인정 수','무료급식소 수']]

# %%
df

# %%
df.to_csv("merged.csv", mode='w')
