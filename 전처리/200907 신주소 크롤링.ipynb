# %%
import os
import pandas as pd
import numpy as np

from google.colab import drive

# %%
if not os.path.exists('/content/drive') :
  drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cd '/content/drive/My Drive/dataset'
# Out:
# /content/drive/My Drive/dataset

# %%
pip install requests beautifulsoup4

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd

# %%
#마산 합포구

html = urlopen("https://www.changwon.go.kr/portal/contents.do?mId=0501020300")

soup = BeautifulSoup(html, 'html.parser')
tables = soup.select('table')
table_html = str(tables)
table_df_list = pd.read_html(table_html)
hap = table_df_list[0]
hap["구"] = "창원시 마산합포구"

# %%
#의창구


html = urlopen("https://www.changwon.go.kr/portal/contents.do?mId=0501020100")

soup = BeautifulSoup(html, 'html.parser')
tables = soup.select('table')
table_html = str(tables)
table_df_list = pd.read_html(table_html)
ui = table_df_list[0]
ui["구"] = "창원시 의창구"
ui
# Out:
#   읍면동명                                               관할구역  비고        구
# 0   동읍  용강리, 용전리, 남산리, 덕천리, 덕산리, 봉산리, 송정리, 용정리, 단계리, 무... NaN  창원시 의창구
# 1   북면  지개리, 고암리, 대산리, 월촌리, 월백리, 화천리 일원중 감계리에 편입된 지번(3... NaN  창원시 의창구
# 2  대산면  갈전리, 일동리, 모산리, 가술리, 제동리, 우암리, 북부리, 유등리, 대방리 중 ... NaN  창원시 의창구
# 3  의창동  북동 일원 소답동 일원 중 명곡동에 편입된 지번(251-2, 253-1, 254-1... NaN  창원시 의창구
# 4  팔룡동  반계동 일원 중 팔용동에 편입된 지번(1441∼1443, 1479, 1480, 14... NaN  창원시 의창구
# 5  명곡동  도계동 일원 중 233, 241-1, 270-1, 273-1, 274-3, 274-... NaN  창원시 의창구
# 6  봉림동  봉곡동 일원 봉림동 일원 지귀동 일원 중 봉곡동에 편입된 지번(489-13, 489... NaN  창원시 의창구
# 7  용지동  용호동 일원 신월동 일원 용지동 일원 중 중앙동에 편입된 지번(272, 273, 3... NaN  창원시 의창구

# %%
#성산구

html = urlopen("https://www.changwon.go.kr/portal/contents.do?mId=0501020200")

soup = BeautifulSoup(html, 'html.parser')
tables = soup.select('table')
table_html = str(tables)
table_df_list = pd.read_html(table_html)
sung = table_df_list[0]
sung["구"] = "창원시 성산구"
sung
# Out:
#    읍면동명                                               관할구역  비고        구
# 0   반송동  반림동 일원 반지동 일원 중 봉곡동에 편입된 지번(501-2번지)을 제외한 반지동 ... NaN  창원시 성산구
# 1   중앙동  내동 일원 중 중앙동에 편입된 지번(1-1, 2-1, 2-2, 3-1, 3-2, 6... NaN  창원시 성산구
# 2   상남동  상남동 일원(62～80,501～502제외), 가음동에 편입된 지번(515-3, 51... NaN  창원시 성산구
# 3   사파동  사파동 일원 사파정동 일원 중 대방동에 편입된 지번(53, 57-1∼57-3, 57... NaN  창원시 성산구
# 4  가음정동  가음동 일원 남양동 일원 대방동 중 308-1, 308-2, 309, 312∼313... NaN  창원시 성산구
# 5   성주동  천선동 일원 중 안민동에 편입된 지번(1147-3, 1173-1, 1235-1, 1... NaN  창원시 성산구
# 6   웅남동  창곡동 일원 중 신촌동에 편입된 지번(77-1, 77-2, 77-7, 77-8, 7... NaN  창원시 성산구

# %%
#마산회원구
html = urlopen("https://www.changwon.go.kr/portal/contents.do?mId=0501020400")

soup = BeautifulSoup(html, 'html.parser')
tables = soup.select('table')
table_html = str(tables)
table_df_list = pd.read_html(table_html)
hoi = table_df_list[0]
hoi["구"] = "창원시 마산회원구"
hoi
# Out:
#     읍면동명                                               관할구역  비고          구
# 0    내서읍    안성리, 평성리, 호계리, 용담리, 중리, 상곡리, 원계리, 삼계리, 신감리, 감천리 NaN  창원시 마산회원구
# 1   회원1동  회원동1-5의78, 19의1-213, 214의2-214의16, 222의1, 224-... NaN  창원시 마산회원구
# 2   회원2동  회원동 214의1, 214의17, 214의23, 215-221, 230-321, 3... NaN  창원시 마산회원구
# 3    석전동  석전동19, 20, 22의4, 22의5, 22의7, 31-35, 40-61, 65-... NaN  창원시 마산회원구
# 4    회성동                                        두척동, 회성동 일원 NaN  창원시 마산회원구
# 5   양덕1동  양덕동1-3, 5, 7, 11-21, 23-26, 28-33, 36, 38-42, ... NaN  창원시 마산회원구
# 6   양덕2동  양덕동57-66, 72-84, 148-169, 173-174, 183의4, 190-... NaN  창원시 마산회원구
# 7   합성1동  합성동54, 56, 60-62, 65-88, 98-101, 114, 115, 119... NaN  창원시 마산회원구
# 8   합성2동  합성동1-53, 55, 57, 59, 63, 64, 89-97, 102, 110, ... NaN  창원시 마산회원구
# 9   구암1동  구암동 3, 6, 8, 10-16, 18-20, 120의1, 120의2, 121의1... NaN  창원시 마산회원구
# 10  구암2동  구암동의5의1, 7의2, 7의8, 9의2, 21-43, 44-48, 50-60, 6... NaN  창원시 마산회원구
# ...

# %%
#진해구

html = urlopen("https://www.changwon.go.kr/portal/contents.do?mId=0501020500")

soup = BeautifulSoup(html, 'html.parser')
tables = soup.select('table')
table_html = str(tables)
table_df_list = pd.read_html(table_html)
jin = table_df_list[0]
jin["구"] = "창원시 진해구"
l = list(jin.columns)
l
# Out:
# ['읍면동명', '관할구역', '비고', '구']

# %%
df_list = [hap, sung, hoi, ui, jin]
table_df = pd.DataFrame(columns=l)
for i in df_list :
  table_df = pd.concat([table_df,i])

# %%
table_df.index = pd.RangeIndex(1,len(table_df.index)+1)
table_df
# Out:
#      읍면동명                                               관할구역   비고          구
# 1     구산면    유산리, 마전리, 석곡리, 수정리, 내포리, 옥계리, 반동리, 구복리, 심리, 난포리  NaN  창원시 마산합포구
# 2     진동면  고현리, 신기리, 사동리, 진동리 일원 중 교동리에 편입된 지번(116의3, 116...  NaN  창원시 마산합포구
# 3     진북면  지산리, 예곡리, 인곡리, 대평리, 이목리, 금산리, 영학리, 부산리, 덕곡리 일원...  NaN  창원시 마산합포구
# 4     진전면  율티리, 근곡리, 임곡리, 봉곡리, 곡안리, 동산리, 양촌리, 봉암리, 일암리, 오...  NaN  창원시 마산합포구
# 5      현동  예곡동 일원 중 우산동에 편입된 지번(109, 156의1, 156의2, 156의6,...  NaN  창원시 마산합포구
# 6     가포동                                             가포동 일원  NaN  창원시 마산합포구
# 7     월영동  월영동 357-702, 732, 산70, 산74의2, 산75, 산76의8, 산76의...  NaN  창원시 마산합포구
# 8     문화동  월영동 1-1의97, 2-2의26, 3의1-3의11, 4의1-4의8, 5의1-5, ...  NaN  창원시 마산합포구
# 9   반월중앙동  반월동, 신월동, 월포동, 장군동 1가, 중앙동 1가 일원, 중앙동 2가 6의 1,...  NaN  창원시 마산합포구
# 10    완월동  장군동 3가 1의4, 1의6-1의8, 1의13, 1의17-1의23, 4의1-4의7,...  NaN  창원시 마산합포구
# 11    자산동                            자산동 일원 교방동 170의2, 170의3  NaN  창원시 마산합포구
# ...
